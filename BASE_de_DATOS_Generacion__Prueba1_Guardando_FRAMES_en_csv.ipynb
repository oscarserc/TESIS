# %% [markdown]
# <a href="https://colab.research.google.com/github/oscarserc/TESIS/blob/main/BASE_de_DATOS_Generacion__Prueba1_Guardando_FRAMES_en_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

matriz = np.empty((5, 5), int)
matriz[0][0] = 2
matriz[0][1] = 3
matriz[1][2] = 4
matriz[1][1] = 6
matriz[2][0] = 2
matriz[2][1] = 3
matriz[3][2] = 4
matriz[3][1] = 6
matriz[4][3] = 8
matriz[4][2] = 7
matriz[4][4] = 1
matriz[0][4] = 2
matriz

plt.imshow(matriz)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

matriz_random = np.random.randn(6,6)

plt.imshow(matriz_random)
plt.show()

# %%
matriz_random.flatten()
# Out:
# array([-4.70809093e-01, -5.90812488e-01,  1.58179929e-02, -1.47286308e+00,
#         1.55443987e+00,  1.35857256e+00, -8.12955278e-02, -9.10146228e-01,
#        -1.85731111e-01, -8.25324836e-02, -6.27068803e-01,  1.59890432e+00,
#         3.49152659e-01,  6.52570789e-01,  9.48097751e-01,  1.06966608e+00,
#        -5.47285913e-01, -1.44724579e-03,  1.31439186e-01,  2.15404375e-01,
#         2.15851522e-01,  8.77579730e-01,  5.89972922e-01,  1.12245550e-01,
#        -7.26160803e-01,  1.37996250e+00,  4.89225743e-01, -1.55024599e-02,
#        -1.38126627e+00,  1.30390189e+00,  6.01090301e-01,  3.34218558e-01,
#        -2.60878259e-01,  1.86283795e-01,  1.56540122e-01, -5.52788799e-01])

# %%
matriz_random_1dim = matriz_random.flatten()

# %%
matriz_random_1dim.ravel()
# Out:
# array([-4.70809093e-01, -5.90812488e-01,  1.58179929e-02, -1.47286308e+00,
#         1.55443987e+00,  1.35857256e+00, -8.12955278e-02, -9.10146228e-01,
#        -1.85731111e-01, -8.25324836e-02, -6.27068803e-01,  1.59890432e+00,
#         3.49152659e-01,  6.52570789e-01,  9.48097751e-01,  1.06966608e+00,
#        -5.47285913e-01, -1.44724579e-03,  1.31439186e-01,  2.15404375e-01,
#         2.15851522e-01,  8.77579730e-01,  5.89972922e-01,  1.12245550e-01,
#        -7.26160803e-01,  1.37996250e+00,  4.89225743e-01, -1.55024599e-02,
#        -1.38126627e+00,  1.30390189e+00,  6.01090301e-01,  3.34218558e-01,
#        -2.60878259e-01,  1.86283795e-01,  1.56540122e-01, -5.52788799e-01])

# %%
import pandas as pd 
pd.DataFrame(matriz_random_1dim.ravel()[None]).to_csv("matriz_aleatoria.csv", index=None)

# %%
datos = pd.read_csv('matriz_aleatoria.csv')
datos
# Out:
#           0         1         2  ...        33       34        35
# 0 -0.470809 -0.590812  0.015818  ...  0.186284  0.15654 -0.552789
#
# [1 rows x 36 columns]

# %% [markdown]
# # **PRUEBA PARA INTENTAR GUARDAR EN UNA FILA SÓLO**

# %%
AUX = matriz_random
AUX.ravel()
# Out:
# array([-4.70809093e-01, -5.90812488e-01,  1.58179929e-02, -1.47286308e+00,
#         1.55443987e+00,  1.35857256e+00, -8.12955278e-02, -9.10146228e-01,
#        -1.85731111e-01, -8.25324836e-02, -6.27068803e-01,  1.59890432e+00,
#         3.49152659e-01,  6.52570789e-01,  9.48097751e-01,  1.06966608e+00,
#        -5.47285913e-01, -1.44724579e-03,  1.31439186e-01,  2.15404375e-01,
#         2.15851522e-01,  8.77579730e-01,  5.89972922e-01,  1.12245550e-01,
#        -7.26160803e-01,  1.37996250e+00,  4.89225743e-01, -1.55024599e-02,
#        -1.38126627e+00,  1.30390189e+00,  6.01090301e-01,  3.34218558e-01,
#        -2.60878259e-01,  1.86283795e-01,  1.56540122e-01, -5.52788799e-01])

# %%
import torch

# LEEMOS DEL DATAFRAME LA PRIMERA FILA
t1 = torch.tensor(datos.iloc[0,:])
# RECUPERAMOS LA FORMA DE MATRIZ
t1_ = t1.view(6,6)

# DIBUJAMOS LOS DATOS de nuevo como una imagen
plt.imshow(t1_)
plt.show()

# %% [markdown]
# # **AHORA PROBAMOS GUARDANDO VARIOS FRAMES**

# %%
import numpy as np
import matplotlib.pyplot as plt

frame_1 = np.random.randn(6,6)

plt.imshow(frame_1)
plt.show()

# %%
frame_2 = np.random.randn(6,6)
plt.imshow(frame_2)
plt.show()

# %%
import pandas as pd

fila1 = frame_1.ravel()
fila2 = frame_2.ravel()

df_1 = pd.DataFrame(fila1[None])
df_1
# Out:
#          0         1         2   ...        33        34        35
# 0 -0.347278  0.670199 -0.054548  ... -0.770217 -0.532916 -1.237188
#
# [1 rows x 36 columns]

# %%
df_aux = pd.DataFrame(fila2[None])
df_aux
# Out:
#          0        1         2   ...        33        34        35
# 0 -0.832809  1.32863 -0.956698  ... -0.104742  1.571868  0.214559
#
# [1 rows x 36 columns]

# %%
df_animacion = df_1.append(df_aux)
df_animacion
# Out:
#          0         1         2   ...        33        34        35
# 0 -0.347278  0.670199 -0.054548  ... -0.770217 -0.532916 -1.237188
# 0 -0.832809  1.328630 -0.956698  ... -0.104742  1.571868  0.214559
#
# [2 rows x 36 columns]

# %%
df_animacion = df_animacion.append(df_aux)
df_animacion
# Out:
#          0         1         2   ...        33        34        35
# 0 -0.347278  0.670199 -0.054548  ... -0.770217 -0.532916 -1.237188
# 0 -0.832809  1.328630 -0.956698  ... -0.104742  1.571868  0.214559
# 0 -0.832809  1.328630 -0.956698  ... -0.104742  1.571868  0.214559
#
# [3 rows x 36 columns]

# %%
import pandas as pd 
pd.DataFrame(frame_1.ravel()[None]).to_csv("animacion.csv", index=None)

# %% [markdown]
# # **PRUEBA COMPLETA 1: Guardo los frames de la ANIMACIÓN como filas de un archivo 'csv'**

# %%
import numpy as np
import matplotlib.pyplot as plt

frame_1 = np.random.randn(6,6)

plt.imshow(frame_1)
plt.show()

# %%
frame_1
# Out:
# array([[-1.41208579, -0.39799926, -0.14790796, -0.45114601,  0.21081987,
#          0.51245589],
#        [ 0.30391929, -0.56890538,  1.61017786, -1.66116805,  0.77441268,
#          0.73442537],
#        [-0.19127952,  0.18872623, -0.61775215,  0.62368915, -1.57325314,
#         -0.94627839],
#        [ 0.83085038, -1.06122552, -0.47715108, -0.77761662, -0.39594976,
#          0.42090693],
#        [-1.6992502 ,  0.15885776, -0.34635618, -1.23866758,  0.36223247,
#          1.53495219],
#        [-0.57020587,  0.07587603, -2.17336549, -0.56763066, -0.10562571,
#          1.59619156]])

# %%
frame_2 = np.random.randn(6,6)
plt.imshow(frame_2)
plt.show()

# %%
df_animacion = pd.DataFrame(frame_1.ravel()[None])
df_animacion
# Out:
#          0         1         2   ...        33        34        35
# 0 -1.412086 -0.397999 -0.147908  ... -0.567631 -0.105626  1.596192
#
# [1 rows x 36 columns]

# %%
frame_nuevo = pd.DataFrame(frame_2.ravel()[None])

df_animacion = df_animacion.append(frame_nuevo)
df_animacion
# Out:
#          0         1         2   ...        33        34        35
# 0 -1.412086 -0.397999 -0.147908  ... -0.567631 -0.105626  1.596192
# 0 -1.729311  0.817708  1.589350  ... -1.547656  0.259739 -2.140183
#
# [2 rows x 36 columns]

# %%
import pandas as pd 
df_animacion.to_csv("animacion.csv", index=None)

# %%
datos_para_la_red = pd.read_csv('animacion.csv')
datos_para_la_red
# Out:
#           0         1         2  ...        33        34        35
# 0 -1.412086 -0.397999 -0.147908  ... -0.567631 -0.105626  1.596192
# 1 -1.729311  0.817708  1.589350  ... -1.547656  0.259739 -2.140183
#
# [2 rows x 36 columns]

# %%
import torch

# LEEMOS DEL DATAFRAME LA PRIMERA FILA
t1 = torch.tensor(datos_para_la_red.iloc[0,:])
# RECUPERAMOS LA FORMA DE MATRIZ 6x6
#t1_ = t1.view(6,6)
#t1_

t1
# Out:
# tensor([-1.4121, -0.3980, -0.1479, -0.4511,  0.2108,  0.5125,  0.3039, -0.5689,
#          1.6102, -1.6612,  0.7744,  0.7344, -0.1913,  0.1887, -0.6178,  0.6237,
#         -1.5733, -0.9463,  0.8309, -1.0612, -0.4772, -0.7776, -0.3959,  0.4209,
#         -1.6993,  0.1589, -0.3464, -1.2387,  0.3622,  1.5350, -0.5702,  0.0759,
#         -2.1734, -0.5676, -0.1056,  1.5962], dtype=torch.float64)

# %%
# RECUPERAMOS LA FORMA DE MATRIZ 6x6
t1_ = t1.view(6,6)
t1_

# DIBUJAMOS LOS DATOS de nuevo como una imagen
plt.imshow(t1_)
plt.show()
